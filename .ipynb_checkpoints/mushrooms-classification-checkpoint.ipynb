# %% [markdown]
# # Load Dataset

# %%
# !pip install gdown
import os
import gdown
import zipfile

if not os.path.isdir("Mushrooms"):
  url = 'https://drive.google.com/uc?id=1BUD8rvVAwon48pnMmUJAKIoZE8AqTRhy'
  output = 'Mushrooms.zip'
  gdown.download(url, output, quiet=False)
  with zipfile.ZipFile(output, 'r') as zip_ref:
    zip_ref.extractall(".")
# Out:
# Collecting gdown
#   Downloading gdown-3.12.2.tar.gz (8.2 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: filelock in /home/alex/anaconda3/lib/python3.8/site-packages (from gdown) (3.0.12)
# Requirement already satisfied: requests[socks] in /home/alex/anaconda3/lib/python3.8/site-packages (from gdown) (2.24.0)
# Requirement already satisfied: tqdm in /home/alex/anaconda3/lib/python3.8/site-packages (from gdown) (4.47.0)
# Requirement already satisfied: six in /home/alex/anaconda3/lib/python3.8/site-packages (from gdown) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from requests[socks]->gdown) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /home/alex/anaconda3/lib/python3.8/site-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alex/anaconda3/lib/python3.8/site-packages (from requests[socks]->gdown) (2020.6.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /home/alex/anaconda3/lib/python3.8/site-packages (from requests[socks]->gdown) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-3.12.2-py3-none-any.whl size=9681 sha256=fcffaca7335baa5eac7d7804de4a90644a149173429795dc29dae22b347b4d8c
#   Stored in directory: /home/alex/.cache/pip/wheels/e2/62/1e/926d1ebe7b1e733c78d627fd288d01b83feaf67efc06e0e4c3
# Successfully built gdown
# Installing collected packages: gdown
# Successfully installed gdown-3.12.2

# %%
# !pip install jupyter_contrib_nbextensions
# !pip install fastai
# !pip install fastai --upgrade
# !pip install opencv-python==3.4.2.16
# !pip install opencv-contrib-python==3.4.2.16
# Out:
# Requirement already satisfied: jupyter_contrib_nbextensions in /home/alex/anaconda3/lib/python3.8/site-packages (0.5.1)
# Requirement already satisfied: lxml in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (4.5.2)
# Requirement already satisfied: tornado in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.0.4)
# Requirement already satisfied: notebook>=4.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.0.3)
# Requirement already satisfied: nbconvert>=4.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (5.6.1)
# Requirement already satisfied: traitlets>=4.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (4.3.3)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.3.3)
# Requirement already satisfied: jupyter-core in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (4.6.3)
# Requirement already satisfied: jupyter-latex-envs>=1.3.8 in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (1.4.6)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.4.1)
# Requirement already satisfied: ipython-genutils in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: pyyaml in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (5.3.1)
# Requirement already satisfied: ipykernel in /home/alex/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (5.3.2)
# Requirement already satisfied: jinja2 in /home/alex/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (2.11.2)
# Requirement already satisfied: jupyter-client>=5.3.4 in /home/alex/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (6.1.6)
# Requirement already satisfied: prometheus-client in /home/alex/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: Send2Trash in /home/alex/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: nbformat in /home/alex/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (5.0.7)
# Requirement already satisfied: pyzmq>=17 in /home/alex/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (19.0.1)
# Requirement already satisfied: bleach in /home/alex/anaconda3/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (3.1.5)
# Requirement already satisfied: testpath in /home/alex/anaconda3/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.4.4)
# Requirement already satisfied: pygments in /home/alex/anaconda3/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.6.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.4.2)
# Requirement already satisfied: defusedxml in /home/alex/anaconda3/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.3)
# Requirement already satisfied: decorator in /home/alex/anaconda3/lib/python3.8/site-packages (from traitlets>=4.1->jupyter_contrib_nbextensions) (4.4.2)
# Requirement already satisfied: six in /home/alex/anaconda3/lib/python3.8/site-packages (from traitlets>=4.1->jupyter_contrib_nbextensions) (1.15.0)
# Requirement already satisfied: setuptools in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (49.2.0.post20200714)
# Requirement already satisfied: ipython in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (7.16.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/alex/anaconda3/lib/python3.8/site-packages (from jinja2->notebook>=4.0->jupyter_contrib_nbextensions) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=4.0->jupyter_contrib_nbextensions) (2.8.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/alex/anaconda3/lib/python3.8/site-packages (from nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (3.2.0)
# Requirement already satisfied: packaging in /home/alex/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (20.4)
# Requirement already satisfied: webencodings in /home/alex/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: jedi>=0.10 in /home/alex/anaconda3/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: pickleshare in /home/alex/anaconda3/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/alex/anaconda3/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: backcall in /home/alex/anaconda3/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (3.0.5)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (0.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.0->jupyter_contrib_nbextensions) (19.3.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from packaging->bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.4.7)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/alex/anaconda3/lib/python3.8/site-packages (from pexpect; sys_platform != "win32"->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.6.0)
# Requirement already satisfied: wcwidth in /home/alex/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: fastai in /home/alex/anaconda3/lib/python3.8/site-packages (2.0.13)
# Requirement already satisfied: pillow in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (7.2.0)
# Requirement already satisfied: torchvision>=0.7 in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (0.7.0)
# Requirement already satisfied: spacy in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (2.3.2)
# Requirement already satisfied: fastcore>=1.0.5 in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (1.0.9)
# Requirement already satisfied: torch>=1.6.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (1.6.0)
# Requirement already satisfied: pyyaml in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (5.3.1)
# Requirement already satisfied: requests in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (2.24.0)
# Requirement already satisfied: scipy in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (1.5.0)
# Requirement already satisfied: packaging in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (20.4)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (1.0.0)
# Requirement already satisfied: pandas in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (1.0.5)
# Requirement already satisfied: matplotlib in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (3.2.2)
# Requirement already satisfied: scikit-learn in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (0.23.1)
# Requirement already satisfied: pip in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (20.1.1)
# Requirement already satisfied: numpy in /home/alex/anaconda3/lib/python3.8/site-packages (from torchvision>=0.7->fastai) (1.18.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (3.0.2)
# Requirement already satisfied: thinc==7.4.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (7.4.1)
# Requirement already satisfied: setuptools in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (49.2.0.post20200714)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (0.8.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (1.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (2.0.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (4.47.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (1.0.2)
# Requirement already satisfied: future in /home/alex/anaconda3/lib/python3.8/site-packages (from torch>=1.6.0->fastai) (0.18.2)
# Requirement already satisfied: idna<3,>=2.5 in /home/alex/anaconda3/lib/python3.8/site-packages (from requests->fastai) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from requests->fastai) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alex/anaconda3/lib/python3.8/site-packages (from requests->fastai) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from requests->fastai) (3.0.4)
# Requirement already satisfied: six in /home/alex/anaconda3/lib/python3.8/site-packages (from packaging->fastai) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from packaging->fastai) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from pandas->fastai) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from pandas->fastai) (2020.1)
# Requirement already satisfied: cycler>=0.10 in /home/alex/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from scikit-learn->fastai) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/alex/anaconda3/lib/python3.8/site-packages (from scikit-learn->fastai) (0.16.0)
# Requirement already up-to-date: fastai in /home/alex/anaconda3/lib/python3.8/site-packages (2.0.13)
# Requirement already satisfied, skipping upgrade: spacy in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (2.3.2)
# Requirement already satisfied, skipping upgrade: requests in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (2.24.0)
# Requirement already satisfied, skipping upgrade: pip in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (20.1.1)
# Requirement already satisfied, skipping upgrade: torchvision>=0.7 in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (0.7.0)
# Requirement already satisfied, skipping upgrade: packaging in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (20.4)
# Requirement already satisfied, skipping upgrade: matplotlib in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (3.2.2)
# Requirement already satisfied, skipping upgrade: pyyaml in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (5.3.1)
# Requirement already satisfied, skipping upgrade: torch>=1.6.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (1.6.0)
# Requirement already satisfied, skipping upgrade: pandas in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (1.0.5)
# Requirement already satisfied, skipping upgrade: fastprogress>=0.2.4 in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (1.0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (0.23.1)
# Requirement already satisfied, skipping upgrade: fastcore>=1.0.5 in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (1.0.9)
# Requirement already satisfied, skipping upgrade: pillow in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (7.2.0)
# Requirement already satisfied, skipping upgrade: scipy in /home/alex/anaconda3/lib/python3.8/site-packages (from fastai) (1.5.0)
# Requirement already satisfied, skipping upgrade: blis<0.5.0,>=0.4.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (0.4.1)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (4.47.0)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (2.0.3)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (1.0.2)
# Requirement already satisfied, skipping upgrade: thinc==7.4.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (7.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (1.18.5)
# Requirement already satisfied, skipping upgrade: plac<1.2.0,>=0.9.6 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (1.1.3)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.4.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (0.8.0)
# Requirement already satisfied, skipping upgrade: setuptools in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (49.2.0.post20200714)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (3.0.2)
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=1.0.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (1.0.2)
# Requirement already satisfied, skipping upgrade: catalogue<1.1.0,>=0.0.7 in /home/alex/anaconda3/lib/python3.8/site-packages (from spacy->fastai) (1.0.0)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /home/alex/anaconda3/lib/python3.8/site-packages (from requests->fastai) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from requests->fastai) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from requests->fastai) (1.25.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /home/alex/anaconda3/lib/python3.8/site-packages (from requests->fastai) (2020.6.20)
# Requirement already satisfied, skipping upgrade: six in /home/alex/anaconda3/lib/python3.8/site-packages (from packaging->fastai) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from packaging->fastai) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (1.2.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /home/alex/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/alex/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied, skipping upgrade: future in /home/alex/anaconda3/lib/python3.8/site-packages (from torch>=1.6.0->fastai) (0.18.2)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/alex/anaconda3/lib/python3.8/site-packages (from pandas->fastai) (2020.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /home/alex/anaconda3/lib/python3.8/site-packages (from scikit-learn->fastai) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /home/alex/anaconda3/lib/python3.8/site-packages (from scikit-learn->fastai) (0.16.0)
# ERROR: Could not find a version that satisfies the requirement opencv-python==3.4.2.16 (from versions: 3.4.8.29, 3.4.9.31, 3.4.9.33, 3.4.10.35, 3.4.10.37, 3.4.11.39, 3.4.11.41, 3.4.11.43, 4.1.2.30, 4.2.0.32, 4.2.0.34, 4.3.0.36, 4.3.0.38, 4.4.0.40, 4.4.0.42, 4.4.0.44)
# ERROR: No matching distribution found for opencv-python==3.4.2.16
# ERROR: Could not find a version that satisfies the requirement opencv-contrib-python==3.4.2.16 (from versions: 3.4.8.29, 3.4.9.31, 3.4.9.33, 3.4.10.35, 3.4.10.37, 3.4.11.39, 3.4.11.41, 3.4.11.43, 4.1.2.30, 4.2.0.32, 4.2.0.34, 4.3.0.36, 4.3.0.38, 4.4.0.40, 4.4.0.42, 4.4.0.44)
# ERROR: No matching distribution found for opencv-contrib-python==3.4.2.16

# %%
import numpy as np 
import pandas as pd 
import os


from fastai.vision.all import *
from fastai.vision.data import ImageDataLoaders
from fastai.metrics import error_rate

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (16, 10) # (w, h)

# %%
batch_size=64
classes = ['Boletus','Entoloma','Russula','Suillus','Lactarius','Amanita','Agaricus','Hygrocybe','Cortinarius']

# %%
path = Path("Mushrooms")
print(path)
# Out:
# Mushrooms

# %%
# Read dataset and split on train and validation sets. Validation = 20% of dataset.
dls_tmp = ImageDataLoaders.from_folder(path,
                                   valid_pct=0.4,
                                   item_tfms=Resize(224),
                                   batch_tfms=Normalize.from_stats(*imagenet_stats),
                                   num_workers=4,
                                   bs=batch_size,
                                   val_bs=batch_size,
                                  )

# %%
import random

def label_func(x): return x.parent.name
def dataloader_from_items(items, valid_pct):
  return ImageDataLoaders.from_path_func(
    path, 
    items, 
    label_func,
    item_tfms=Resize(224),
    batch_tfms=Normalize.from_stats(*imagenet_stats),
    num_workers=4,
    valid_pct=valid_pct,
    bs=batch_size)

valid_items = dls_tmp.valid.items
random.shuffle(valid_items)
# Split validation set on two equal parts: test and validation.
# Resulting sizes (approximately) train: 64%, validation: 16%, test: 20% of the dataset.
# Note: test should have batches of equal sizes (64 by default), otherwise predictions will crush.
test_dls = dataloader_from_items(valid_items[:len(valid_items)//batch_size//2*batch_size], valid_pct=0.0)
dls = dataloader_from_items(valid_items[len(valid_items)//batch_size//2*batch_size:]+dls_tmp.train.items, valid_pct=0.2)
print("Train size: {}, Validation size: {}, Test size: {}".format(
    len(dls.train.items), len(dls.valid.items), len(test_dls.items)))
# Out:
# Train size: 4348, Validation size: 1086, Test size: 1280

# %%
print("Train/Validation")
dls.show_batch()
# Out:
# Train/Validation

# %%
print("Test")
test_dls.show_batch()
# Out:
# Test

# %% [markdown]
# # Helper functions

# %%
def show_in_row(list_of_images, titles = None, disable_ticks = False):
  count = len(list_of_images)
  for idx in range(count):
    subplot = plt.subplot(1, count, idx+1)
    if titles is not None:
      subplot.set_title(titles[idx])
      
    img = list_of_images[idx]
    cmap = 'gray' if (len(img.shape) == 2 or img.shape[2] == 1) else None
    subplot.imshow(img, cmap=cmap)
    if disable_ticks:
      plt.xticks([]), plt.yticks([])
  plt.show()

def tensor_to_numpy_image(img):
  # this converts it from GPU to CPU and selects first image
  img = img.cpu().numpy()
  #convert image back to Height,Width,Channels
  img = np.transpose(img, (1,2,0))
  img = img.astype(np.uint8)
  #show the image
  return img

# %% [markdown]
# # Train model

# %%
from PIL import ImageFile
import fastai.vision.models as models
significant_reduce = 1e-2
max_iterations = 5

ImageFile.LOAD_TRUNCATED_IMAGES = True
def train(learner):
  prev_loss = 1e9
  iteration = 0
  # Fine tune while validation loss reduces significantly
  while iteration < max_iterations 
  and (learner.recorder.loss.value is None or prev_loss - learner.recorder.loss.value > significant_reduce):
    iteration += 1
    if learner.recorder.loss.value is not None:
      prev_loss = learner.recorder.loss.value
    else:
      prev_loss = 1e9
    lr = learner.lr_find()[0]
    learner.recorder.before_epoch()
    learner.fine_tune(epochs=4, lr=lr)
    learner.recorder.after_epoch()
    
  interp = ClassificationInterpretation.from_learner(learner)
  interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
  return learner

def init_model(dls, model):
  learner = cnn_learner(dls, model, metrics=error_rate)
  learner.recorder.loss.reset()
  return learner
# Out:
#   File "<ipython-input-12-beb81f9b95b0>", line 11
#     while iteration < max_iterations
#                                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# # ResNet50

# %%
rn50_learner = init_model(dls, models.resnet50)
train(rn50_learner)

# %%
rn50_learner.summary()

# %% [markdown]
# # ResNet101

# %%
rn101_learner = init_model(dls, models.resnet101)
train(rn101_learner)

# %%
rn101_learner.summary()

# %% [markdown]
# # Alexnet

# %%
alexnet_learner = init_model(dls, models.alexnet)
train(alexnet_learner)

# %%
alexnet_learner.summary()

# %% [markdown]
# # VGG16

# %%
vgg16_learner = init_model(dls, models.vgg16_bn)
train(vgg16_learner)

# %%
vgg16_learner.summary()

# %% [markdown]
# # VGG19

# %%
vgg19_learner = init_model(dls, models.vgg19_bn)
train(vgg19_learner)

# %%
vgg19_learner.summary()

# %% [markdown]
# # Comparison

# %%
accuracies = []
CNNs = ["ResNet50", "ResNet101", "Alexnet", "VGG16", "VGG19"]

accuracies.append(accuracy(*rn50_learner.get_preds(dl=test_dls)).item())
accuracies.append(accuracy(*rn101_learner.get_preds(dl=test_dls)).item())
accuracies.append(accuracy(*alexnet_learner.get_preds(dl=test_dls)).item())
accuracies.append(accuracy(*vgg16_learner.get_preds(dl=test_dls)).item())
accuracies.append(accuracy(*vgg19_learner.get_preds(dl=test_dls)).item())

# %%
y_pos = np.arange(len(CNNs))
for i in range(len(accuracies)):
  print("{} test accuracy: {}".format(CNNs[i], accuracies[i]))

plt.bar(y_pos, accuracies, align='center', alpha=0.5)
plt.xticks(y_pos, CNNs)
plt.ylabel('Test set accuracy')
plt.title("CNNs' comparison")

plt.show()
